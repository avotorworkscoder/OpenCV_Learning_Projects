# %%
"""
The Project
Classifying Simple Shapes (Circle vs Square)

Why this example?
Because it mirrors real tasks like:

1.Sorting components

2.Detecting defective parts

3.Classifying objects on a conveyor

And it works with images you can easily generate.
    
    
We’ll build one clean pipeline and explain each part:

1. Feature extraction

2. Train/test split

3. ML classifier on images

4. Evaluate accuracy

5. Compare classical vs ML

"""

# %%
# Step 1: Feature Extraction

import cv2
import numpy as np

def extract_features(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) == 0:
        return None

    cnt = max(contours, key=cv2.contourArea)

    area = cv2.contourArea(cnt)
    perimeter = cv2.arcLength(cnt, True)

    x,y,w,h = cv2.boundingRect(cnt)
    aspect_ratio = w / float(h)

    circularity = 4*np.pi*area/(perimeter*perimeter) if perimeter!=0 else 0

    return [area, perimeter, aspect_ratio, circularity]

# %%
# Step 2: Build Dataset

# Python Script for bing image downloader
from bing_image_downloader import downloader

# Download circles
downloader.download(
    "perfect circle white background", 
    limit=100, 
    output_dir='dataset', 
    adult_filter_off=True, 
    force_replace=False, 
    filter="clipart", # Options: line, photo, clipart, gif, transparent
    verbose=True
)

# Download squares
downloader.download(
    "perfect square white background", 
    limit=100, 
    output_dir='dataset', 
    adult_filter_off=True, 
    force_replace=False, 
    filter="clipart",
    verbose=True
)
# Out:
# [%] Downloading Images to f:\Python code\Opencv\dataset\perfect circle white background
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.freepnglogos.com/uploads/circle-png/black-and-white-round-frame-circle-png-7.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://storage.needpix.com/rsynced_images/white-circle.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.freepik.com/premium-vector/pink-white-circle-with-white-background-with-red-circle-white-background_822882-55642.jpg?w=2000
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://thumbs.dreamstime.com/b/watercolor-circle-white-background-watercolor-circle-white-as-background-169530287.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-psd/orange-background-with-white-circle-white-circle_551318-1453.jpg?w=996
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://st3.depositphotos.com/1359043/32163/i/1600/depositphotos_321630404-stock-illustration-watercolor-circle-white-background.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://img.freepik.com/premium-vector/colorful-circle-white-background-isolated-transparent-background_764382-3840.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://thumbs.dreamstime.com/z/image-green-circle-white-background-293334970.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://img.freepik.com/premium-photo/black-circle-with-white-background_1046600-147.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://thumbs.dreamstime.com/z/vector-image-abstract-blue-circle-white-background-frame-illustrations-clipart-258521280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://thumbs.dreamstime.com/z/round-soft-white-circle-background-neomorphism-abstract-minmal-modern-element-template-d-illustration-282119127.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://img.freepik.com/premium-vector/black-white-picture-circle-white-background_706143-118433.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://img.freepik.com/premium-vector/red-circle-white-background-vector_613054-77.jpg?w=2000
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://static.vecteezy.com/system/resources/thumbnails/015/638/783/original/circle-white-audio-spectrum-green-screen-background-free-video.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://img.freepik.com/premium-photo/abstract-minimalist-watercolor-circle-white-background_772785-5231.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://img.freepik.com/premium-photo/abstract-minimalist-watercolor-circle-white-background_772785-5232.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://image.shutterstock.com/image-illustration/drawing-beautiful-circle-white-background-260nw-50255389.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://wallpaperaccess.com/full/967597.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://img.freepik.com/premium-photo/abstract-minimalist-watercolor-circle-white-background_772785-2709.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://www.shutterstock.com/image-vector/vector-icon-circle-white-background-260nw-2063560706.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://img.freepik.com/premium-photo/green-watercolor-paint-shape-circle-white-background_392895-114251.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://i.pinimg.com/originals/b4/6a/64/b46a64880bc7fb30b42cdab4956f7b82.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from http://www.clker.com/cliparts/n/4/f/D/x/u/black-circle-medium-outline-hi.png
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://thumbs.dreamstime.com/b/abstract-colorful-circle-white-background-vector-58399283.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://i0.wp.com/www.freepnglogos.com/uploads/circle-png/red-circle-hq-transparent-background-24.png
# [!] Issue getting: https://i0.wp.com/www.freepnglogos.com/uploads/circle-png/red-circle-hq-transparent-background-24.png
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #25 from https://phonenumble.com/images/games/perfect-circle.png
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://img.freepik.com/premium-vector/colorful-flat-design-icons-circle-white-background_1280751-31543.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://static.vecteezy.com/system/resources/previews/021/053/982/original/perfect-circle-icon-frame-free-png.png
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://img.freepik.com/premium-vector/vector-3d-purple-circle-white-background_921039-3497.jpg?w=2000
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://thumbs.dreamstime.com/b/brown-coffee-cup-stain-ring-forming-perfect-circle-white-background-breakfast-lunch-cafe-restaurant-morning-concepts-368899247.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://www.logotypes101.com/logos/632/74000587C4E39271F88B7510BEEE3D74/A_Perfect_Circle.png
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://img.freepik.com/premium-photo/minimalist-black-brushstroke-forming-circle-white-background_797688-3219.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://static.vecteezy.com/system/resources/thumbnails/021/998/058/small_2x/hand-drawn-circle-highlighting-free-png.png
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://static.vecteezy.com/system/resources/thumbnails/021/998/552/small_2x/hand-drawn-circle-highlighting-free-png.png
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://static.vecteezy.com/system/resources/thumbnails/035/861/254/small_2x/red-white-circle-darts-target-with-orange-arrow-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #35 from https://static.vecteezy.com/system/resources/thumbnails/058/990/612/small_2x/red-circle-on-white-background-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #36 from https://static.vecteezy.com/system/resources/previews/013/980/785/non_2x/abstract-circle-pattern-abstract-blue-white-geometric-small-circle-and-half-circle-random-shape-seamless-pattern-background-use-for-fabric-interior-decoration-elements-upholstery-wrapping-vector.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #37 from https://static.vecteezy.com/system/resources/thumbnails/038/367/734/small_2x/loading-circle-sign-icon-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #38 from https://static.vecteezy.com/system/resources/thumbnails/055/144/292/small_2x/watercolor-red-circle-painting-with-soft-gradient-hues-abstract-art-with-a-blend-of-red-and-white-shades-for-creative-design-projects-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #39 from https://img.freepik.com/premium-photo/painting-pink-circle-with-white-background-generative-ai_1034560-42038.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #40 from https://static.vecteezy.com/system/resources/thumbnails/010/850/940/small_2x/vintage-retro-logo-isolated-on-transparent-background-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #41 from https://static.vecteezy.com/system/resources/thumbnails/053/289/900/small_2x/simple-black-outline-circle-on-white-background-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #42 from https://static.vecteezy.com/system/resources/thumbnails/021/998/557/small_2x/hand-drawn-circle-highlighting-free-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #43 from https://img.freepik.com/premium-photo/close-up-green-plant-circle-white-background-generative-ai_1034068-28089.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #44 from https://static.vecteezy.com/system/resources/thumbnails/047/392/764/small_2x/purple-and-white-round-circle-frame-organic-round-blot-circle-speech-cycle-blob-bubble-line-curve-free-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #45 from https://static.vecteezy.com/system/resources/thumbnails/049/952/119/small_2x/golden-glitter-circle-on-a-white-background-cut-out-transparent-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #46 from https://static.vecteezy.com/system/resources/thumbnails/024/524/098/small_2x/circle-border-illustration-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #47 from https://images.all-free-download.com/images/graphiclarge/abstract_white_circle_illustration_background_vector_6819504.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #48 from https://www.shutterstock.com/shutterstock/photos/2244322169/display_1500/stock-photo-perfect-circle-of-blank-background-2244322169.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
# [%] Downloading Image #49 from https://img.freepik.com/premium-photo/there-is-circle-made-colored-circles-white-background-generative-ai_1034470-40718.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #50 from https://thumbs.dreamstime.com/b/abstract-red-circle-white-background-grainy-noise-effect-minimalistic-digital-texture-patriotic-design-abstract-358859611.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #51 from https://i.pinimg.com/originals/8e/5c/2a/8e5c2a9f1d29e9530f8e1c48b0952c4e.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #52 from https://cdn.wallpapersafari.com/99/94/bF6OJ2.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #53 from https://thumbs.dreamstime.com/z/abstract-blue-circles-white-background-abstract-blue-circles-white-background-isolated-white-177137760.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
# [%] Downloading Image #54 from https://as2.ftcdn.net/v2/jpg/03/53/15/25/1000_F_353152513_w2u3qD8i3aexYr07t2TIjIOZnftclZ7X.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #55 from https://png.pngtree.com/png-clipart/20230126/original/pngtree-circle-logo-design-banner-shape-vector-free-transparent-background-png-image_8931626.png
# [!] Issue getting: https://png.pngtree.com/png-clipart/20230126/original/pngtree-circle-logo-design-banner-shape-vector-free-transparent-background-png-image_8931626.png
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
# [%] Downloading Image #55 from https://static.vecteezy.com/system/resources/previews/016/314/339/original/red-circle-red-dot-icon-free-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #56 from https://play-lh.googleusercontent.com/uk4w2-hWuZjgKWOqvbno6bG3jaw5WqUKM2kiXG0_KS--QX0joYwwhyg-0YodE085Ng
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
# [%] Downloading Image #57 from https://www.citypng.com/public/uploads/preview/marker-sketch-orange-circle-hd-png-11664728000wymwozz5d7.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
# [%] Downloading Image #58 from https://wallpapers.com/images/hd/perfect-circle-graphic-png-hmw48-bjtfhoy5cd8wr0rk.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
# [%] Downloading Image #59 from https://i.pinimg.com/736x/c1/28/2d/c1282df2d016d473a4fe0a9337965b11.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
# [%] Downloading Image #60 from https://www.vedantu.com/seo/content-images/f049afa1-814d-4059-811f-a041b6562fe1.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 35 Images on Page 32.
#
# ===============================================
#
# [%] Downloading Image #61 from https://www.publicdomainpictures.net/pictures/310000/velka/blue-circle.png
# [!] Issue getting: https://www.publicdomainpictures.net/pictures/310000/velka/blue-circle.png
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 35 Images on Page 33.
#
# ===============================================
#
# [%] Downloading Image #61 from https://www.freepnglogos.com/uploads/circle-png/red-simple-download-circle-image-10.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 35 Images on Page 34.
#
# ===============================================
#
# [%] Downloading Image #62 from https://png.pngtree.com/png-clipart/20221220/original/pngtree-yellow-circle-background-for-element-banner-png-image_8785918.png
# [!] Issue getting: https://png.pngtree.com/png-clipart/20221220/original/pngtree-yellow-circle-background-for-element-banner-png-image_8785918.png
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 35 Images on Page 35.
#
# ===============================================
#
# [%] Downloading Image #62 from https://cdn1.vectorstock.com/i/1000x1000/67/00/circle-stamp-frame-on-white-background-red-vector-19576700.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 35 Images on Page 36.
#
# ===============================================
#
# [%] Downloading Image #63 from https://i.pinimg.com/originals/da/2c/80/da2c80e66fe4bd3a539631bbc8724a8f.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 35 Images on Page 37.
#
# ===============================================
#
# [%] Downloading Image #64 from https://cdn4.vectorstock.com/i/1000x1000/77/78/white-round-background-with-colorful-dotted-vector-21967778.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 35 Images on Page 38.
#
# ===============================================
#
# [%] Downloading Image #65 from https://heywhatsgoingon.com/wp-content/uploads/2025/04/Final_Update_Circle_White-Background-1024x1024.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 39
#
# [%] Indexed 35 Images on Page 39.
#
# ===============================================
#
# [%] Downloading Image #66 from https://pixy.org/src/452/thumbs350/4526341.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 40
#
# [%] Indexed 35 Images on Page 40.
#
# ===============================================
#
# [%] Downloading Image #67 from https://i.pinimg.com/originals/dc/a2/1b/dca21be92ef10ecd0b4974fa648d6df3.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 41
#
# [%] Indexed 35 Images on Page 41.
#
# ===============================================
#
# [%] Downloading Image #68 from https://i.pinimg.com/originals/31/c9/7c/31c97c6395cca06769b0806c89586d2a.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 42
#
# [%] Indexed 35 Images on Page 42.
#
# ===============================================
#
# [%] Downloading Image #69 from https://i.pinimg.com/originals/f9/e8/ca/f9e8ca6c4493582dffa46a751f543824.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 43
#
# [%] Indexed 35 Images on Page 43.
#
# ===============================================
#
# [%] Downloading Image #70 from https://static.vecteezy.com/system/resources/previews/021/662/385/original/red-circle-free-png.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 44
#
# [%] Indexed 34 Images on Page 44.
#
# ===============================================
#
#
#
# [!!]Indexing page: 45
#
# [%] Indexed 34 Images on Page 45.
#
# ===============================================
#
# [%] Downloading Image #71 from https://pixy.org/src/452/4526341.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 46
#
# [%] Indexed 34 Images on Page 46.
#
# ===============================================
#
# [%] Downloading Image #72 from https://dijf55il5e0d1.cloudfront.net/images/na/3/9/4/39413_1000.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 47
#
# [%] Indexed 34 Images on Page 47.
#
# ===============================================
#
# [%] Downloading Image #73 from https://www.citypng.com/public/uploads/preview/doodle-sketch-lines-red-circle-transparent-png-116650733751g7zsbsolw.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 48
#
# [%] Indexed 34 Images on Page 48.
#
# ===============================================
#
# [%] Downloading Image #74 from https://www.publicdomainpictures.net/pictures/230000/nahled/white-circle.jpg
# [!] Issue getting: https://www.publicdomainpictures.net/pictures/230000/nahled/white-circle.jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 49
#
# [%] Indexed 33 Images on Page 49.
#
# ===============================================
#
#
#
# [!!]Indexing page: 50
#
# [%] Indexed 32 Images on Page 50.
#
# ===============================================
#
#
#
# [!!]Indexing page: 51
#
# [%] Indexed 31 Images on Page 51.
#
# ===============================================
#
#
#
# [!!]Indexing page: 52
#
# [%] Indexed 30 Images on Page 52.
#
# ===============================================
#
#
#
# [!!]Indexing page: 53
#
# [%] Indexed 29 Images on Page 53.
#
# ===============================================
#
#
#
# [!!]Indexing page: 54
#
# [%] Indexed 28 Images on Page 54.
#
# ===============================================
#
#
#
# [!!]Indexing page: 55
#
# [%] Indexed 28 Images on Page 55.
#
# ===============================================
#
#
#
# [!!]Indexing page: 56
#
# [%] Indexed 27 Images on Page 56.
#
# ===============================================
#
#
#
# [!!]Indexing page: 57
#
# [%] Indexed 26 Images on Page 57.
#
# ===============================================
#
#
#
# [!!]Indexing page: 58
#
# [%] Indexed 25 Images on Page 58.
#
# ===============================================
#
#
#
# [!!]Indexing page: 59
#
# [%] Indexed 24 Images on Page 59.
#
# ===============================================
#
#
#
# [!!]Indexing page: 60
#
# [%] Indexed 23 Images on Page 60.
#
# ===============================================
#
#
#
# [!!]Indexing page: 61
#
# [%] Indexed 22 Images on Page 61.
#
# ===============================================
#
#
#
# [!!]Indexing page: 62
#
# [%] Indexed 21 Images on Page 62.
#
# ===============================================
#
#
#
# [!!]Indexing page: 63
#
# [%] Indexed 20 Images on Page 63.
#
# ===============================================
#
#
#
# [!!]Indexing page: 64
#
# [%] Indexed 19 Images on Page 64.
#
# ===============================================
#
#
#
# [!!]Indexing page: 65
#
# [%] Indexed 18 Images on Page 65.
#
# ===============================================
#
#
#
# [!!]Indexing page: 66
#
# [%] Indexed 17 Images on Page 66.
#
# ===============================================
#
#
#
# [!!]Indexing page: 67
#
# [%] Indexed 16 Images on Page 67.
#
# ===============================================
#
#
#
# [!!]Indexing page: 68
#
# [%] Indexed 15 Images on Page 68.
#
# ===============================================
#
#
#
# [!!]Indexing page: 69
#
# [%] Indexed 14 Images on Page 69.
#
# ===============================================
#
#
#
# [!!]Indexing page: 70
#
# [%] Indexed 13 Images on Page 70.
#
# ===============================================
#
#
#
# [!!]Indexing page: 71
#
# [%] Indexed 12 Images on Page 71.
#
# ===============================================
#
#
#
# [!!]Indexing page: 72
#
# [%] Indexed 11 Images on Page 72.
#
# ===============================================
#
#
#
# [!!]Indexing page: 73
#
# [%] Indexed 10 Images on Page 73.
#
# ===============================================
#
#
#
# [!!]Indexing page: 74
#
# [%] Indexed 9 Images on Page 74.
#
# ===============================================
#
#
#
# [!!]Indexing page: 75
#
# [%] Indexed 8 Images on Page 75.
#
# ===============================================
#
#
#
# [!!]Indexing page: 76
#
# [%] Indexed 7 Images on Page 76.
#
# ===============================================
#
#
#
# [!!]Indexing page: 77
#
# [%] Indexed 6 Images on Page 77.
#
# ===============================================
#
#
#
# [!!]Indexing page: 78
#
# [%] Indexed 5 Images on Page 78.
#
# ===============================================
#
#
#
# [!!]Indexing page: 79
#
# [%] Indexed 4 Images on Page 79.
#
# ===============================================
#
#
#
# [!!]Indexing page: 80
#
# [%] Indexed 3 Images on Page 80.
#
# ===============================================
#
#
#
# [!!]Indexing page: 81
#
# [%] Indexed 2 Images on Page 81.
#
# ===============================================
#
#
#
# [!!]Indexing page: 82
#
# [%] Indexed 1 Images on Page 82.
#
# ===============================================
#
#
#
# [!!]Indexing page: 83
#
# [%] Indexed 11 Images on Page 83.
#
# ===============================================
#
#
#
# [!!]Indexing page: 84
#
# [%] Indexed 11 Images on Page 84.
#
# ===============================================
#
#
#
# [!!]Indexing page: 85
#
# [%] Indexed 11 Images on Page 85.
#
# ===============================================
#
#
#
# [!!]Indexing page: 86
#
# [%] Indexed 11 Images on Page 86.
#
# ===============================================
#
#
#
# [!!]Indexing page: 87
#
# [%] Indexed 11 Images on Page 87.
#
# ===============================================
#
#
#
# [!!]Indexing page: 88
#
# [%] Indexed 11 Images on Page 88.
#
# ===============================================
#
#
#
# [!!]Indexing page: 89
#
# [%] Indexed 11 Images on Page 89.
#
# ===============================================
#
#
#
# [!!]Indexing page: 90
#
# [%] Indexed 11 Images on Page 90.
#
# ===============================================
#
#
#
# [!!]Indexing page: 91
#
# [%] Indexed 11 Images on Page 91.
#
# ===============================================
#
#
#
# [!!]Indexing page: 92
#
# [%] Indexed 11 Images on Page 92.
#
# ===============================================
#
#
#
# [!!]Indexing page: 93
#
# [%] Indexed 11 Images on Page 93.
#
# ===============================================
#
#
#
# [!!]Indexing page: 94
#
# [%] Indexed 11 Images on Page 94.
#
# ===============================================
#
#
#
# [!!]Indexing page: 95
#
# [%] Indexed 11 Images on Page 95.
#
# ===============================================
#
#
#
# [!!]Indexing page: 96
#
# [%] Indexed 11 Images on Page 96.
#
# ===============================================
#
#
#
# [!!]Indexing page: 97
#
# [%] Indexed 11 Images on Page 97.
#
# ===============================================
#
#
#
# [!!]Indexing page: 98
#
# [%] Indexed 11 Images on Page 98.
#
# ===============================================
#
#
#
# [!!]Indexing page: 99
#
# [%] Indexed 11 Images on Page 99.
#
# ===============================================
#
#
#
# [!!]Indexing page: 100
#
# [%] Indexed 11 Images on Page 100.
#
# ===============================================
#
#
#
# [!!]Indexing page: 101
#
# [%] Indexed 11 Images on Page 101.
#
# ===============================================
#
#
#
# [!!]Indexing page: 102
#
# [%] Indexed 11 Images on Page 102.
#
# ===============================================
#
#
#
# [!!]Indexing page: 103
#
# [%] Indexed 11 Images on Page 103.
#
# ===============================================
#
#
#
# [!!]Indexing page: 104
#
# [%] Indexed 11 Images on Page 104.
#
# ===============================================
#
#
#
# [!!]Indexing page: 105
#
# [%] Indexed 11 Images on Page 105.
#
# ===============================================
#
#
#
# [!!]Indexing page: 106
#
# [%] Indexed 11 Images on Page 106.
#
# ===============================================
#
#
#
# [!!]Indexing page: 107
#
# [%] Indexed 11 Images on Page 107.
#
# ===============================================
#
#
#
# [!!]Indexing page: 108
#
# [%] Indexed 11 Images on Page 108.
#
# ===============================================
#
#
#
# [!!]Indexing page: 109
#
# [%] Indexed 11 Images on Page 109.
#
# ===============================================
#
#
#
# [!!]Indexing page: 110
#
# [%] Indexed 11 Images on Page 110.
#
# ===============================================
#
#
#
# [!!]Indexing page: 111
#
# [%] Indexed 11 Images on Page 111.
#
# ===============================================
#
#
#
# [!!]Indexing page: 112
#
# [%] Indexed 11 Images on Page 112.
#
# ===============================================
#
#
#
# [!!]Indexing page: 113
#
# [%] Indexed 11 Images on Page 113.
#
# ===============================================
#
#
#
# [!!]Indexing page: 114
#
# [%] Indexed 11 Images on Page 114.
#
# ===============================================
#
#
#
# [!!]Indexing page: 115
#
# [%] Indexed 11 Images on Page 115.
#
# ===============================================
#
#
#
# [!!]Indexing page: 116
#
# [%] Indexed 11 Images on Page 116.
#
# ===============================================
#
#
#
# [!!]Indexing page: 117
#
# [%] Indexed 11 Images on Page 117.
#
# ===============================================
#
#
#
# [!!]Indexing page: 118
#
# [%] Indexed 11 Images on Page 118.
#
# ===============================================
#
#
#
# [!!]Indexing page: 119
#
# [%] Indexed 11 Images on Page 119.
#
# ===============================================
#
#
#
# [!!]Indexing page: 120
#
# [%] Indexed 11 Images on Page 120.
#
# ===============================================
#
#
#
# [!!]Indexing page: 121
#
# [%] Indexed 11 Images on Page 121.
#
# ===============================================
#
#
#
# [!!]Indexing page: 122
#
# [%] Indexed 11 Images on Page 122.
#
# ===============================================
#
#
#
# [!!]Indexing page: 123
#
# [%] Indexed 11 Images on Page 123.
#
# ===============================================
#
#
#
# [!!]Indexing page: 124
#
# [%] Indexed 11 Images on Page 124.
#
# ===============================================
#
#
#
# [!!]Indexing page: 125
#
# [%] Indexed 11 Images on Page 125.
#
# ===============================================
#
#
#
# [!!]Indexing page: 126
#
# [%] Indexed 11 Images on Page 126.
#
# ===============================================
#
#
#
# [!!]Indexing page: 127
#
# [%] Indexed 11 Images on Page 127.
#
# ===============================================
#
#
#
# [!!]Indexing page: 128
#
# [%] Indexed 11 Images on Page 128.
#
# ===============================================
#
#
#
# [!!]Indexing page: 129
#
# [%] Indexed 11 Images on Page 129.
#
# ===============================================
#
#
#
# [!!]Indexing page: 130
#
# [%] Indexed 11 Images on Page 130.
#
# ===============================================
#
#
#
# [!!]Indexing page: 131
#
# [%] Indexed 11 Images on Page 131.
#
# ===============================================
#
#
#
# [!!]Indexing page: 132
#
# [%] Indexed 11 Images on Page 132.
#
# ===============================================
#
#
#
# [!!]Indexing page: 133
#
# [%] Indexed 11 Images on Page 133.
#
# ===============================================
#
#
#
# [!!]Indexing page: 134
#
# [%] Indexed 11 Images on Page 134.
#
# ===============================================
#
#
#
# [!!]Indexing page: 135
#
# [%] Indexed 11 Images on Page 135.
#
# ===============================================
#
#
#
# [!!]Indexing page: 136
#
# [%] Indexed 11 Images on Page 136.
#
# ===============================================
#
#
#
# [!!]Indexing page: 137
#
# [%] Indexed 11 Images on Page 137.
#
# ===============================================
#
#
#
# [!!]Indexing page: 138
#
# [%] Indexed 11 Images on Page 138.
#
# ===============================================
#
#
#
# [!!]Indexing page: 139
#
# [%] Indexed 11 Images on Page 139.
#
# ===============================================
#
#
#
# [!!]Indexing page: 140
#
# [%] Indexed 11 Images on Page 140.
#
# ===============================================
#
#
#
# [!!]Indexing page: 141
#
# [%] Indexed 11 Images on Page 141.
#
# ===============================================
#
#
#
# [!!]Indexing page: 142
#
# [%] Indexed 11 Images on Page 142.
#
# ===============================================
#
#
#
# [!!]Indexing page: 143
#
# [%] Indexed 11 Images on Page 143.
#
# ===============================================
#
#
#
# [!!]Indexing page: 144
#
# [%] Indexed 11 Images on Page 144.
#
# ===============================================
#
#
#
# [!!]Indexing page: 145
#
# [%] Indexed 11 Images on Page 145.
#
# ===============================================
#
#
#
# [!!]Indexing page: 146
#
# [%] Indexed 11 Images on Page 146.
#
# ===============================================
#
#
#
# [!!]Indexing page: 147
#
# [%] Indexed 11 Images on Page 147.
#
# ===============================================
#
#
#
# [!!]Indexing page: 148
#
# [%] Indexed 11 Images on Page 148.
#
# ===============================================
#
#
#
# [!!]Indexing page: 149
#
# [%] Indexed 11 Images on Page 149.
#
# ===============================================
#
#
#
# [!!]Indexing page: 150
#
# [%] Indexed 11 Images on Page 150.
#
# ===============================================
#
#
#
# [!!]Indexing page: 151
#
# [%] Indexed 11 Images on Page 151.
#
# ===============================================
#
#
#
# [!!]Indexing page: 152
#
# [%] Indexed 11 Images on Page 152.
#
# ===============================================
#
#
#
# [!!]Indexing page: 153
#
# [%] Indexed 11 Images on Page 153.
#
# ===============================================
#
#
#
# [!!]Indexing page: 154
#
# [%] Indexed 11 Images on Page 154.
#
# ===============================================
#
#
#
# [!!]Indexing page: 155
#
# [%] Indexed 11 Images on Page 155.
#
# ===============================================
#
#
#
# [!!]Indexing page: 156
#
# [%] Indexed 11 Images on Page 156.
#
# ===============================================
#
#
#
# [!!]Indexing page: 157
#
# [%] Indexed 11 Images on Page 157.
#
# ===============================================
#
#
#
# [!!]Indexing page: 158
#
# [%] Indexed 11 Images on Page 158.
#
# ===============================================
#
#
#
# [!!]Indexing page: 159
#
# [%] Indexed 11 Images on Page 159.
#
# ===============================================
#
#
#
# [!!]Indexing page: 160
#
# [%] Indexed 11 Images on Page 160.
#
# ===============================================
#
#
#
# [!!]Indexing page: 161
#
# [%] Indexed 11 Images on Page 161.
#
# ===============================================
#
#
#
# [!!]Indexing page: 162
#
# [%] Indexed 11 Images on Page 162.
#
# ===============================================
#
#
#
# [!!]Indexing page: 163
#
# [%] Indexed 11 Images on Page 163.
#
# ===============================================
#
#
#
# [!!]Indexing page: 164
#
# [%] Indexed 11 Images on Page 164.
#
# ===============================================
#
#
#
# [!!]Indexing page: 165
#
# [%] Indexed 11 Images on Page 165.
#
# ===============================================
#
#
#
# [!!]Indexing page: 166
#
# [%] Indexed 11 Images on Page 166.
#
# ===============================================
#
#
#
# [!!]Indexing page: 167
#
# [%] Indexed 11 Images on Page 167.
#
# ===============================================
#
#
#
# [!!]Indexing page: 168
#
# [%] Indexed 11 Images on Page 168.
#
# ===============================================
#
#
#
# [!!]Indexing page: 169
#
# [%] Indexed 11 Images on Page 169.
#
# ===============================================
#
#
#
# [!!]Indexing page: 170
#
# [%] Indexed 11 Images on Page 170.
#
# ===============================================
#
#
#
# [!!]Indexing page: 171
#
# [%] Indexed 11 Images on Page 171.
#
# ===============================================
#
#
#
# [!!]Indexing page: 172
#
# [%] Indexed 11 Images on Page 172.
#
# ===============================================
#
#
#
# [!!]Indexing page: 173
#
# [%] Indexed 11 Images on Page 173.
#
# ===============================================
#
#
#
# [!!]Indexing page: 174
#
# [%] Indexed 11 Images on Page 174.
#
# ===============================================
#
#
#
# [!!]Indexing page: 175
#
# [%] Indexed 11 Images on Page 175.
#
# ===============================================
#
#
#
# [!!]Indexing page: 176
#
# [%] Indexed 11 Images on Page 176.
#
# ===============================================
#
#
#
# [!!]Indexing page: 177
#
# [%] Indexed 11 Images on Page 177.
#
# ===============================================
#
#
#
# [!!]Indexing page: 178
#
# [%] Indexed 11 Images on Page 178.
#
# ===============================================
#
#
#
# [!!]Indexing page: 179
#
# [%] Indexed 11 Images on Page 179.
#
# ===============================================
#
#
#
# [!!]Indexing page: 180
#
# [%] Indexed 11 Images on Page 180.
#
# ===============================================
#
#
#
# [!!]Indexing page: 181
#
# [%] Indexed 11 Images on Page 181.
#
# ===============================================
#
#
#
# [!!]Indexing page: 182
#
# [%] Indexed 11 Images on Page 182.
#
# ===============================================
#
#
#
# [!!]Indexing page: 183
#
# [%] Indexed 11 Images on Page 183.
#
# ===============================================
#
#
#
# [!!]Indexing page: 184
#
# [%] Indexed 11 Images on Page 184.
#
# ===============================================
#
#
#
# [!!]Indexing page: 185
#
# [%] Indexed 11 Images on Page 185.
#
# ===============================================
#
#
#
# [!!]Indexing page: 186
#
# [%] Indexed 11 Images on Page 186.
#
# ===============================================
#
#
#
# [!!]Indexing page: 187
#
# [%] Indexed 11 Images on Page 187.
#
# ===============================================
#
#
#
# [!!]Indexing page: 188
#
# [%] Indexed 11 Images on Page 188.
#
# ===============================================
#
#
#
# [!!]Indexing page: 189
#
# [%] Indexed 11 Images on Page 189.
#
# ===============================================
#
#
#
# [!!]Indexing page: 190
#
# [%] Indexed 11 Images on Page 190.
#
# ===============================================
#
#
#
# [!!]Indexing page: 191
#
# [%] Indexed 11 Images on Page 191.
#
# ===============================================
#
#
#
# [!!]Indexing page: 192
#
# [%] Indexed 11 Images on Page 192.
#
# ===============================================
#
#
#
# [!!]Indexing page: 193
#
# [%] Indexed 11 Images on Page 193.
#
# ===============================================
#
#
#
# [!!]Indexing page: 194
#
# [%] Indexed 11 Images on Page 194.
#
# ===============================================
#
#
#
# [!!]Indexing page: 195
#
# [%] Indexed 11 Images on Page 195.
#
# ===============================================
#
#
#
# [!!]Indexing page: 196
#
# [%] Indexed 11 Images on Page 196.
#
# ===============================================
#
#
#
# [!!]Indexing page: 197
#
# [%] Indexed 11 Images on Page 197.
#
# ===============================================
#
#
#
# [!!]Indexing page: 198
#
# [%] Indexed 11 Images on Page 198.
#
# ===============================================
#
#
#
# [!!]Indexing page: 199
#
# [%] Indexed 11 Images on Page 199.
#
# ===============================================
#
#
#
# [!!]Indexing page: 200
#
# [%] Indexed 11 Images on Page 200.
#
# ===============================================
#
#
#
# [!!]Indexing page: 201
#
# [%] Indexed 11 Images on Page 201.
#
# ===============================================
#
#
#
# [!!]Indexing page: 202
#
# [%] Indexed 11 Images on Page 202.
#
# ===============================================
#
#
#
# [!!]Indexing page: 203
#
# [%] Indexed 11 Images on Page 203.
#
# ===============================================
#
#
#
# [!!]Indexing page: 204
#
# [%] Indexed 11 Images on Page 204.
#
# ===============================================
#
#
#
# [!!]Indexing page: 205
#
# [%] Indexed 11 Images on Page 205.
#
# ===============================================
#
#
#
# [!!]Indexing page: 206
#
# [%] Indexed 11 Images on Page 206.
#
# ===============================================
#
#
#
# [!!]Indexing page: 207
#
# [%] Indexed 11 Images on Page 207.
#
# ===============================================
#
#
#
# [!!]Indexing page: 208
#
# [%] Indexed 11 Images on Page 208.
#
# ===============================================
#
#
#
# [!!]Indexing page: 209
#
# [%] Indexed 11 Images on Page 209.
#
# ===============================================
#
#
#
# [!!]Indexing page: 210
#
# [%] Indexed 11 Images on Page 210.
#
# ===============================================
#
#
#
# [!!]Indexing page: 211
#
# [%] Indexed 11 Images on Page 211.
#
# ===============================================
#
#
#
# [!!]Indexing page: 212
#
# [%] Indexed 11 Images on Page 212.
#
# ===============================================
#
#
#
# [!!]Indexing page: 213
#
# [%] Indexed 11 Images on Page 213.
#
# ===============================================
#
#
#
# [!!]Indexing page: 214
#
# [%] Indexed 11 Images on Page 214.
#
# ===============================================
#
#
#
# [!!]Indexing page: 215
#
# [%] Indexed 11 Images on Page 215.
#
# ===============================================
#
#
#
# [!!]Indexing page: 216
#
# [%] Indexed 11 Images on Page 216.
#
# ===============================================
#
#
#
# [!!]Indexing page: 217
#
# [%] Indexed 11 Images on Page 217.
#
# ===============================================
#
#
#
# [!!]Indexing page: 218
#
# [%] Indexed 11 Images on Page 218.
#
# ===============================================
#
#
#
# [!!]Indexing page: 219
#
# [%] Indexed 11 Images on Page 219.
#
# ===============================================
#
#
#
# [!!]Indexing page: 220
#
# [%] Indexed 11 Images on Page 220.
#
# ===============================================
#
#
#
# [!!]Indexing page: 221
#
# [%] Indexed 11 Images on Page 221.
#
# ===============================================
#
#
#
# [!!]Indexing page: 222
#
# [%] Indexed 11 Images on Page 222.
#
# ===============================================
#
#
#
# [!!]Indexing page: 223
#
# [%] Indexed 11 Images on Page 223.
#
# ===============================================
#
#
#
# [!!]Indexing page: 224
#
# [%] Indexed 11 Images on Page 224.
#
# ===============================================
#
#
#
# [!!]Indexing page: 225
#
# [%] Indexed 11 Images on Page 225.
#
# ===============================================
#
#
#
# [!!]Indexing page: 226
#
# [%] Indexed 11 Images on Page 226.
#
# ===============================================
#
#
#
# [!!]Indexing page: 227
#
# [%] Indexed 11 Images on Page 227.
#
# ===============================================
#
#
#
# [!!]Indexing page: 228
#
# [%] Indexed 11 Images on Page 228.
#
# ===============================================
#
#
#
# [!!]Indexing page: 229
#
# [%] Indexed 11 Images on Page 229.
#
# ===============================================
#
#
#
# [!!]Indexing page: 230
#
# [%] Indexed 11 Images on Page 230.
#
# ===============================================
#
#
#
# [!!]Indexing page: 231
#
# [%] Indexed 11 Images on Page 231.
#
# ===============================================
#
#
#
# [!!]Indexing page: 232
#
# [%] Indexed 11 Images on Page 232.
#
# ===============================================
#
#
#
# [!!]Indexing page: 233
#
# [%] Indexed 11 Images on Page 233.
#
# ===============================================
#
#
#
# [!!]Indexing page: 234
#
# [%] Indexed 11 Images on Page 234.
#
# ===============================================
#
#
#
# [!!]Indexing page: 235
#
# [%] Indexed 11 Images on Page 235.
#
# ===============================================
#
#
#
# [!!]Indexing page: 236
#
# [%] Indexed 11 Images on Page 236.
#
# ===============================================
#
#
#
# [!!]Indexing page: 237
#
# [%] Indexed 11 Images on Page 237.
#
# ===============================================
#
#
#
# [!!]Indexing page: 238
#
# [%] Indexed 11 Images on Page 238.
#
# ===============================================
#
#
#
# [!!]Indexing page: 239
#
# [%] Indexed 11 Images on Page 239.
#
# ===============================================
#
#
#
# [!!]Indexing page: 240
#
# [%] Indexed 11 Images on Page 240.
#
# ===============================================
#
#
#
# [!!]Indexing page: 241
#
# [%] Indexed 11 Images on Page 241.
#
# ===============================================
#
#
#
# [!!]Indexing page: 242
#
# [%] Indexed 11 Images on Page 242.
#
# ===============================================
#
#
#
# [!!]Indexing page: 243
#
# [%] Indexed 11 Images on Page 243.
#
# ===============================================
#
#
#
# [!!]Indexing page: 244
#
# [%] Indexed 11 Images on Page 244.
#
# ===============================================
#
#
#
# [!!]Indexing page: 245
#
# [%] Indexed 11 Images on Page 245.
#
# ===============================================
#
#
#
# [!!]Indexing page: 246
#
# [%] Indexed 11 Images on Page 246.
#
# ===============================================
#
#
#
# [!!]Indexing page: 247
#
# [%] Indexed 11 Images on Page 247.
#
# ===============================================
#
#
#
# [!!]Indexing page: 248
#
# [%] Indexed 11 Images on Page 248.
#
# ===============================================
#
#
#
# [!!]Indexing page: 249
#
# [%] Indexed 11 Images on Page 249.
#
# ===============================================
#
#
#
# [!!]Indexing page: 250
#
# [%] Indexed 11 Images on Page 250.
#
# ===============================================
#
#
#
# [!!]Indexing page: 251
#
# [%] Indexed 11 Images on Page 251.
#
# ===============================================
#
#
#
# [!!]Indexing page: 252
#
# [%] Indexed 11 Images on Page 252.
#
# ===============================================
#
#
#
# [!!]Indexing page: 253
#
# [%] Indexed 11 Images on Page 253.
#
# ===============================================
#
#
#
# [!!]Indexing page: 254
#
# [%] Indexed 11 Images on Page 254.
#
# ===============================================
#
#
#
# [!!]Indexing page: 255
#
# [%] Indexed 11 Images on Page 255.
#
# ===============================================
#
#
#
# [!!]Indexing page: 256
#
# [%] Indexed 11 Images on Page 256.
#
# ===============================================
#
#
#
# [!!]Indexing page: 257
#
# [%] Indexed 11 Images on Page 257.
#
# ===============================================
#
#
#
# [!!]Indexing page: 258
#
# [%] Indexed 11 Images on Page 258.
#
# ===============================================
#
#
#
# [!!]Indexing page: 259
#
# [%] Indexed 11 Images on Page 259.
#
# ===============================================
#
#
#
# [!!]Indexing page: 260
#
# [%] Indexed 11 Images on Page 260.
#
# ===============================================
#
#
#
# [!!]Indexing page: 261
#
# [%] Indexed 11 Images on Page 261.
#
# ===============================================
#
#
#
# [!!]Indexing page: 262
#
# [%] Indexed 11 Images on Page 262.
#
# ===============================================
#
#
#
# [!!]Indexing page: 263
#
# [%] Indexed 11 Images on Page 263.
#
# ===============================================
#
#
#
# [!!]Indexing page: 264
#
# [%] Indexed 11 Images on Page 264.
#
# ===============================================
#
#
#
# [!!]Indexing page: 265
#
# [%] Indexed 11 Images on Page 265.
#
# ===============================================
#
#
#
# [!!]Indexing page: 266
#
# [%] Indexed 11 Images on Page 266.
#
# ===============================================
#
#
#
# [!!]Indexing page: 267
#
# [%] Indexed 11 Images on Page 267.
#
# ===============================================
#
#
#
# [!!]Indexing page: 268
#
# [%] Indexed 11 Images on Page 268.
#
# ===============================================
#
#
#
# [!!]Indexing page: 269
#
# [%] Indexed 11 Images on Page 269.
#
# ===============================================
#
#
#
# [!!]Indexing page: 270
#
# [%] Indexed 11 Images on Page 270.
#
# ===============================================
#
#
#
# [!!]Indexing page: 271
#
# [%] Indexed 11 Images on Page 271.
#
# ===============================================
#
#
#
# [!!]Indexing page: 272
#
# [%] Indexed 11 Images on Page 272.
#
# ===============================================
#
#
#
# [!!]Indexing page: 273
#
# [%] Indexed 11 Images on Page 273.
#
# ===============================================
#
#
#
# [!!]Indexing page: 274
#
# [%] Indexed 11 Images on Page 274.
#
# ===============================================
#
#
#
# [!!]Indexing page: 275
#
# [%] Indexed 11 Images on Page 275.
#
# ===============================================
#
#
#
# [!!]Indexing page: 276
#
# [%] Indexed 11 Images on Page 276.
#
# ===============================================
#
#
#
# [!!]Indexing page: 277
#
# [%] Indexed 11 Images on Page 277.
#
# ===============================================
#
#
#
# [!!]Indexing page: 278
#
# [%] Indexed 11 Images on Page 278.
#
# ===============================================
#
#
#
# [!!]Indexing page: 279
#
# [%] Indexed 11 Images on Page 279.
#
# ===============================================
#
#
#
# [!!]Indexing page: 280
#
# [%] Indexed 11 Images on Page 280.
#
# ===============================================
#
#
#
# [!!]Indexing page: 281
#
# [%] Indexed 11 Images on Page 281.
#
# ===============================================
#
#
#
# [!!]Indexing page: 282
#
# [%] Indexed 11 Images on Page 282.
#
# ===============================================
#
#
#
# [!!]Indexing page: 283
#
# [%] Indexed 11 Images on Page 283.
#
# ===============================================
#
#
#
# [!!]Indexing page: 284
#
# [%] Indexed 11 Images on Page 284.
#
# ===============================================
#
#
#
# [!!]Indexing page: 285
#
# [%] Indexed 11 Images on Page 285.
#
# ===============================================
#
#
#
# [!!]Indexing page: 286
#
# [%] Indexed 11 Images on Page 286.
#
# ===============================================
#
#
#
# [!!]Indexing page: 287
#
# [%] Indexed 11 Images on Page 287.
#
# ===============================================
#
#
#
# [!!]Indexing page: 288
#
# [%] Indexed 11 Images on Page 288.
#
# ===============================================
#
#
#
# [!!]Indexing page: 289
#
# [%] Indexed 11 Images on Page 289.
#
# ===============================================
#
#
#
# [!!]Indexing page: 290
#
# [%] Indexed 11 Images on Page 290.
#
# ===============================================
#
#
#
# [!!]Indexing page: 291
#
# [%] Indexed 11 Images on Page 291.
#
# ===============================================
#
#
#
# [!!]Indexing page: 292
#
# [%] Indexed 11 Images on Page 292.
#
# ===============================================
#
#
#
# [!!]Indexing page: 293
#
# [%] Indexed 11 Images on Page 293.
#
# ===============================================
#
#
#
# [!!]Indexing page: 294
#
# [%] Indexed 11 Images on Page 294.
#
# ===============================================
#
#
#
# [!!]Indexing page: 295
#
# [%] Indexed 11 Images on Page 295.
#
# ===============================================
#
#
#
# [!!]Indexing page: 296
#
# [%] Indexed 11 Images on Page 296.
#
# ===============================================
#
#
#
# [!!]Indexing page: 297
#
# [%] Indexed 11 Images on Page 297.
#
# ===============================================
#
#
#
# [!!]Indexing page: 298
#
# [%] Indexed 11 Images on Page 298.
#
# ===============================================
#
#
#
# [!!]Indexing page: 299
#
# [%] Indexed 11 Images on Page 299.
#
# ===============================================
#
#
#
# [!!]Indexing page: 300
#
# [%] Indexed 11 Images on Page 300.
#
# ===============================================
#
#
#
# [!!]Indexing page: 301
#
# [%] Indexed 11 Images on Page 301.
#
# ===============================================
#
#
#
# [!!]Indexing page: 302
#
# [%] Indexed 11 Images on Page 302.
#
# ===============================================
#
#
#
# [!!]Indexing page: 303
#
# [%] Indexed 11 Images on Page 303.
#
# ===============================================
#
#
#
# [!!]Indexing page: 304
#
# [%] Indexed 11 Images on Page 304.
#
# ===============================================
#
#
#
# [!!]Indexing page: 305
#
# [%] Indexed 11 Images on Page 305.
#
# ===============================================
#
#
#
# [!!]Indexing page: 306
#
# [%] Indexed 11 Images on Page 306.
#
# ===============================================
#
#
#
# [!!]Indexing page: 307
#
# [%] Indexed 11 Images on Page 307.
#
# ===============================================
#
#
#
# [!!]Indexing page: 308
#
# [%] Indexed 11 Images on Page 308.
#
# ===============================================
#
#
#
# [!!]Indexing page: 309
#
# [%] Indexed 11 Images on Page 309.
#
# ===============================================
#
#
#
# [!!]Indexing page: 310
#
# [%] Indexed 11 Images on Page 310.
#
# ===============================================
#
#
#
# [!!]Indexing page: 311
#
# [%] Indexed 11 Images on Page 311.
#
# ===============================================
#
#
#
# [!!]Indexing page: 312
#
# [%] Indexed 11 Images on Page 312.
#
# ===============================================
#
#
#
# [!!]Indexing page: 313
#
# [%] Indexed 11 Images on Page 313.
#
# ...
#
# ===============================================
#
#
#
# [!!]Indexing page: 1211
#
# [%] Indexed 11 Images on Page 1211.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1212
#
# [%] Indexed 11 Images on Page 1212.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1213
#
# [%] Indexed 11 Images on Page 1213.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1214
#
# [%] Indexed 11 Images on Page 1214.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1215
#
# [%] Indexed 11 Images on Page 1215.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1216
#
# [%] Indexed 11 Images on Page 1216.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1217
#
# [%] Indexed 11 Images on Page 1217.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1218
#
# [%] Indexed 11 Images on Page 1218.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1219
#
# [%] Indexed 11 Images on Page 1219.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1220
#
# [%] Indexed 11 Images on Page 1220.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1221
#
# [%] Indexed 11 Images on Page 1221.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1222
#
# [%] Indexed 11 Images on Page 1222.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1223
#
# [%] Indexed 11 Images on Page 1223.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1224
#
# [%] Indexed 11 Images on Page 1224.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1225
#
# [%] Indexed 11 Images on Page 1225.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1226
#
# [%] Indexed 11 Images on Page 1226.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1227
#
# [%] Indexed 11 Images on Page 1227.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1228
#
# [%] Indexed 11 Images on Page 1228.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1229
#
# [%] Indexed 11 Images on Page 1229.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1230
#
# [%] Indexed 11 Images on Page 1230.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1231
#
# [%] Indexed 11 Images on Page 1231.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1232
#
# [%] Indexed 11 Images on Page 1232.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1233
#
# [%] Indexed 11 Images on Page 1233.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1234
#
# [%] Indexed 11 Images on Page 1234.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1235
#
# [%] Indexed 11 Images on Page 1235.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1236
#
# [%] Indexed 11 Images on Page 1236.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1237
#
# [%] Indexed 11 Images on Page 1237.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1238
#
# [%] Indexed 11 Images on Page 1238.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1239
#
# [%] Indexed 11 Images on Page 1239.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1240
#
# [%] Indexed 11 Images on Page 1240.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1241
#
# [%] Indexed 11 Images on Page 1241.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1242
#
# [%] Indexed 11 Images on Page 1242.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1243
#
# [%] Indexed 11 Images on Page 1243.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1244
#
# [%] Indexed 11 Images on Page 1244.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1245
#
# [%] Indexed 11 Images on Page 1245.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1246
#
# [%] Indexed 11 Images on Page 1246.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1247
#
# [%] Indexed 11 Images on Page 1247.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1248
#
# [%] Indexed 11 Images on Page 1248.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1249
#
# [%] Indexed 11 Images on Page 1249.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1250
#
# [%] Indexed 11 Images on Page 1250.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1251
#
# [%] Indexed 11 Images on Page 1251.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1252
#
# [%] Indexed 11 Images on Page 1252.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1253
#
# [%] Indexed 11 Images on Page 1253.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1254
#
# [%] Indexed 11 Images on Page 1254.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1255
#
# [%] Indexed 11 Images on Page 1255.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1256
#
# [%] Indexed 11 Images on Page 1256.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1257
#
# [%] Indexed 11 Images on Page 1257.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1258
#
# [%] Indexed 11 Images on Page 1258.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1259
#
# [%] Indexed 11 Images on Page 1259.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1260
#
# [%] Indexed 11 Images on Page 1260.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1261
#
# [%] Indexed 11 Images on Page 1261.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1262
#
# [%] Indexed 11 Images on Page 1262.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1263
#
# [%] Indexed 11 Images on Page 1263.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1264
#
# [%] Indexed 11 Images on Page 1264.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1265
#
# [%] Indexed 11 Images on Page 1265.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1266
#
# [%] Indexed 11 Images on Page 1266.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1267
#
# [%] Indexed 11 Images on Page 1267.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1268
#
# [%] Indexed 11 Images on Page 1268.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1269
#
# [%] Indexed 11 Images on Page 1269.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1270
#
# [%] Indexed 11 Images on Page 1270.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1271
#
# [%] Indexed 11 Images on Page 1271.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1272
#
# [%] Indexed 11 Images on Page 1272.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1273
#
# [%] Indexed 11 Images on Page 1273.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1274
#
# [%] Indexed 11 Images on Page 1274.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1275
#
# [%] Indexed 11 Images on Page 1275.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1276
#
# [%] Indexed 11 Images on Page 1276.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1277
#
# [%] Indexed 11 Images on Page 1277.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1278
#
# [%] Indexed 11 Images on Page 1278.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1279
#
# [%] Indexed 11 Images on Page 1279.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1280
#
# [%] Indexed 11 Images on Page 1280.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1281
#
# [%] Indexed 11 Images on Page 1281.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1282
#
# [%] Indexed 11 Images on Page 1282.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1283
#
# [%] Indexed 11 Images on Page 1283.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1284
#
# [%] Indexed 11 Images on Page 1284.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1285
#
# [%] Indexed 11 Images on Page 1285.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1286
#
# [%] Indexed 11 Images on Page 1286.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1287
#
# [%] Indexed 11 Images on Page 1287.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1288
#
# [%] Indexed 11 Images on Page 1288.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1289
#
# [%] Indexed 11 Images on Page 1289.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1290
#
# [%] Indexed 11 Images on Page 1290.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1291
#
# [%] Indexed 11 Images on Page 1291.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1292
#
# [%] Indexed 11 Images on Page 1292.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1293
#
# [%] Indexed 11 Images on Page 1293.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1294
#
# [%] Indexed 11 Images on Page 1294.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1295
#
# [%] Indexed 11 Images on Page 1295.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1296
#
# [%] Indexed 11 Images on Page 1296.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1297
#
# [%] Indexed 11 Images on Page 1297.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1298
#
# [%] Indexed 11 Images on Page 1298.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1299
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 7
#       4 from bing_image_downloader import downloader
#       6 # Download circles
# ----> 7 downloader.download(
#       8     "perfect circle white background",
#       9     limit=290,
#      10     output_dir='dataset',
#      11     adult_filter_off=True,
#      12     force_replace=False,
#      13     filter="clipart", # Options: line, photo, clipart, gif, transparent
#      14     verbose=True
#      15 )
#      17 # Download squares
#      18 downloader.download(
#      19     "perfect square white background",
#      20     limit=200,
#    (...)     25     verbose=True
#      26 )
#
# File f:\Python code\.venv\Lib\site-packages\bing_image_downloader\downloader.py:38, in download(query, limit, output_dir, adult_filter_off, force_replace, timeout, filter, verbose)
#      36 print("[%] Downloading Images to {}".format(str(image_dir.absolute())))
#      37 bing = Bing(query, limit, image_dir, adult, timeout, filter, verbose)
# ---> 38 bing.run()
#
# File f:\Python code\.venv\Lib\site-packages\bing_image_downloader\bing.py:99, in Bing.run(self)
#      95 request_url = 'https://www.bing.com/images/async?q=' + urllib.parse.quote_plus(self.query) \
#      96               + '&first=' + str(self.page_counter) + '&count=' + str(self.limit) \
#      97               + '&adlt=' + self.adult + '&qft=' + ('' if self.filter is None else self.get_filter(self.filter))
#      98 request = urllib.request.Request(request_url, None, headers=self.headers)
# ---> 99 response = urllib.request.urlopen(request)
#     100 html = response.read().decode('utf8')
#     101 if html ==  "":
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:1323, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1321     except OSError as err: # timeout error
#    1322         raise URLError(err)
# -> 1323     r = h.getresponse()
#    1324 except:
#    1325     h.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Python Script for compressed numpy arrays images
import numpy as np

# Saving multiple arrays
#x = np.arange(10)
#y = np.sin(x)
#np.savez('data.npz', x=x, y=y)

# Loading the file
container = np.load('shapes.npz')
print(container.files)

for key in container.files:
    print(f"Key: {key}, Shape: {container[key].shape}")

container = np.load('shapes.npz')

X_train = container['X_train']
y_train = container['y_train']
X_test  = container['X_test']
y_test  = container['y_test']

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

print(X_train.shape)
print(X_train.dtype)
# Out:
# ['X_train', 'y_train', 'X_test', 'y_test']
# Key: X_train, Shape: (7500, 64, 64)
# Key: y_train, Shape: (7500,)
# Key: X_test, Shape: (2500, 64, 64)
# Key: y_test, Shape: (2500,)
# (7500, 64, 64) (7500,)
# (2500, 64, 64) (2500,)
# (7500, 64, 64)
# float64

# %%
# Icrawler script
from icrawler.builtin import GoogleImageCrawler
import os

# Define the target classes and counts
tasks = {
    'perfect circle white background': 290,
    'perfect square white background': 200
}

# Advanced Filters: Ensuring white background and clipart style
# 'color' can be: 'color', 'blackandwhite', 'red', 'orange', 'yellow', 'green', 'teal', 'blue', 'purple', 'pink', 'white', 'gray', 'black', 'brown'
filters = dict(
    type='clipart',
    color='white',
    size='medium'
)

for keyword, count in tasks.items():
    # Setup directory to match your Step 3 loading logic
    save_dir = os.path.join('dataset', keyword)
    
    # Initialize Crawler
    # downloader_threads=4 makes it much faster than bing-downloader
    crawler = GoogleImageCrawler(
        storage={'root_dir': save_dir},
        downloader_threads=4 
    )
    
    print(f"--- Starting download for: {keyword} ---")
    
    crawler.crawl(
        keyword=keyword,
        filters=filters,
        max_num=count,
        min_size=(100, 100) # Ensures we don't get tiny icons
    )

print("Dataset Download Complete!")

# %%
# Step 3: Load Dataset

import os

X = []
y = []

dataset_path = "dataset"

for label, folder in enumerate(["perfect circle white background","perfect square white background"]):
    folder_path = os.path.join(dataset_path, folder)

    for file in os.listdir(folder_path):
        path = os.path.join(folder_path, file)
        img = cv2.imread(path)

        features = extract_features(img)
        if features is not None:
            X.append(features)
            y.append(label)

# %%
# Step 3: Train/Test Split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Step 4: ML Classifier

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Step 5: Evaluate Accuracy

from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5714285714285714

# %%
img = cv2.imread("dataset/img/square.jpg")
features = extract_features(img)

prediction = model.predict([features])

if prediction[0] == 0:
    print("Circle")
else:
    print("Square")
# Out:
# Square

# %%
import cv2
import numpy as np

# 1. Initialize Webcam
cap = cv2.VideoCapture(0)

print("Starting Robot Vision... Press 'q' to exit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # --- DETECTION LOGIC (Finding the object) ---
    # We use the same preprocessing as your 'extract_features' function
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Blur helps the webcam handle flickering lights
    blurred = cv2.GaussianBlur(gray, (25, 25), 0)
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for cnt in contours:
        # Ignore tiny noise/specks
        if cv2.contourArea(cnt) < 1000:
            continue

        # --- FEATURE EXTRACTION (Objective 1) ---
        # We must extract the EXACT same features used to train the model
        area = cv2.contourArea(cnt)
        perimeter = cv2.arcLength(cnt, True)
        
        x, y, w, h = cv2.boundingRect(cnt)
        aspect_ratio = w / float(h)
        circularity = 4 * np.pi * area / (perimeter * perimeter) if perimeter != 0 else 0

        # Create the feature vector for the model
        current_features = [area, perimeter, aspect_ratio, circularity]

        # --- CLASSIFICATION (Objective 2) ---
        # The model expects a 2D array: [[f1, f2, f3, f4]]
        prediction = model.predict([current_features])
        
        # Mapping numerical labels back to text
        if prediction[0] == 0:
            label = "Circle"
            color = (0, 255, 0) # Green for circle
        else:
            label = "Square"
            color = (255, 0, 0) # Blue for square

        # --- VISUALIZATION ---
        # Draw the bounding box
        cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
        # Draw the label text
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    # Display the result
    cv2.imshow("Robot Perception - Live Classification", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Starting Robot Vision... Press 'q' to exit.
